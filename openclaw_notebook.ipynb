# %% [markdown]
# # OpenCLAW Installation Notebook
#
# This notebook sets up the environment and installs OpenCLAW.

# %% [markdown]
# ## Step 1: Check Python Version

# %%
import sys
print(f"Python version: {sys.version}")

# %% [markdown]
# ## Step 2: Upgrade pip

# %%
# !pip install --upgrade pip

# %% [markdown]
# ## Step 3: Install OpenCLAW

# %%
# !pip install openclaw

# %% [markdown]
# ## Step 4: Verify Installation

# %%
try:
    import openclaw
    print(f"OpenCLAW version: {openclaw.__version__ if hasattr(openclaw, '__version__') else 'installed'}")
    print("✓ OpenCLAW installed successfully!")
except ImportError as e:
    print(f"Import error: {e}")
    print("Trying to install additional dependencies...")
    # !pip install openclaw[all]  # or specific extras

# %% [markdown]
# ## Step 5: Check Docker (Optional)

# %%
import subprocess
import shutil

# Check if Docker is installed
docker_path = shutil.which("docker")
if docker_path:
    print(f"✓ Docker found at: {docker_path}")
    try:
        result = subprocess.run(["docker", "--version"], capture_output=True, text=True)
        print(f"Docker version: {result.stdout.strip()}")
    except Exception as e:
        print(f"Could not get Docker version: {e}")
else:
    print("✗ Docker not found in PATH")
    print("Install Docker from: https://docs.docker.com/get-docker/")

# %% [markdown]
# ## Step 6: Basic Usage Example

# %%
# Example of how to use OpenCLAW
# (uncomment and modify as needed)

# import openclaw
# client = openclaw.Client()
# result = client.analyze("your input")
# print(result)

# %% [markdown]
# ## Step 7: List Installed Packages

# %%
# !pip list | grep -i claw
